# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto - Part 3

# %% [markdown]
# ### Actual code of Part 3 starts from row 21

# %% [markdown]
# ## Importing required Libraries

# %%
from bs4 import BeautifulSoup   #Python package for parsing HTML and XML documents

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# %matplotlib inline

# import k-means from clustering stage
from sklearn.cluster import KMeans

 #!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Libraries imported.

# %% [markdown]
# ### Assigning wikipedia Article to __*url*__

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# ### Prasing table using *requests* and *BeautifulSoup*

# %%
req=requests.get(url)
data=req.text
    
soup = BeautifulSoup(data,"html.parser")
table = soup.table

# %% [markdown]
# ### __*table*__ now has all the table data in wikipedia article

# %%
table_rows=[] # creating an empty list

# %% [markdown]
# #### Iterating over *'tr'* and *'td'* tags in __'table'__

# %% [markdown]
# When in __*'td'*__ tag, search for __*'a'*__ tag and then get the title by doing this we can filter the Grayed Out and Not Assigned cells

# %% [markdown]
# Grayed Out and Not Assigned cells will be replaced by __*'None'*__

# %% [markdown]
# Extracting table data into __*table_rows*__

# %%
trs=table.find_all('tr')
for tr in trs:
    td = tr.find_all('td')
    if len(td)==0:
        continue
    postal_code = td[0].getText()
    district = td[1].find('a')
    if district is None:
        dist_name = 'None'
    else:
        dist_name = district.getText() 
    Neighborhood = td[2].find('a')
    if Neighborhood is None:
        Neig_hood = 'None'
    else:
        Neig_hood = Neighborhood.getText()
    table_rows.append([postal_code,dist_name,Neig_hood])

# %% [markdown]
# #### Creating Dataframe from __*table_rows*__ and assigning column names

# %%
df=pd.DataFrame(table_rows,columns=['PostalCode','Borough','Neighborhood'])

# %% [markdown]
# #### Filtering the rows which has 'None'.
# 'None' indicates grayed out and Not assigned cells

# %%
df1=df[df['Neighborhood'] != 'None']

# %%
df2=df1[df1['Borough'] != 'None']

# %%
df3=df2.reset_index()

# %%
df4=df3.drop('index',axis=1)

# %% [markdown]
# #### Below step joins values in Neighborhood column based on postalCode and Borough

# %%
p_codes=df4.groupby(['PostalCode','Borough'])['Neighborhood'].apply(','.join).reset_index()

# %%
p_codes.head()
# Out:
#   PostalCode      Borough                          Neighborhood
# 0        M1B  Scarborough                         Rouge,Malvern
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough                 Morningside,West Hill
# 3        M1G  Scarborough                                Woburn
# 4        M1H  Scarborough                             Cedarbrae

# %%
p_codes.shape
# Out:
# (84, 3)

# %%
df5=p_codes  # copying Dataframe 'P-codes' to df5

# %% [markdown]
# ### Creating 2 functions to get Latitude and Longitude

# %% [markdown]
# I'm using "Geolocator" tool insted of geocoder which was given to us for sample
#
# I'm using Neighboorhod and Borough to get the latitude and longitude.

# %%
# Function for getting Latitude
def lat(elem):
    n,b=elem
    n1=list(n.split(","))
    a='{},{}'.format(n1[0],b)
    geolocator = Nominatim()
    location = geolocator.geocode(a)
    if location == None:
        location = geolocator.geocode(b)
        latitude = location.latitude
        longitude = location.longitude
    else:
        latitude = location.latitude
        longitude = location.longitude
    return latitude

# %%
# Function for getting Longitude
def lng(elem):
    n,b=elem
    n1=list(n.split(","))
    a='{},{}'.format(n1[0],b)
    #print(a)
    geolocator = Nominatim()
    location = geolocator.geocode(a)
    if location == None:
        location = geolocator.geocode(b)
        latitude = location.latitude
        longitude = location.longitude
    else:
        latitude = location.latitude
        longitude = location.longitude
    return longitude

# %% [markdown]
# #### Applying functions and getting latittude and Longitude

# %%
df5['latitude'] = df5[['Neighborhood','Borough']].apply(lat,axis=1)
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
df5['longitude'] = df5[['Neighborhood','Borough']].apply(lng,axis=1)
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
df5.head()
# Out:
#   PostalCode      Borough                          Neighborhood   latitude  \
# 0        M1B  Scarborough                         Rouge,Malvern  43.804930
# 1        M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.790117
# 2        M1E  Scarborough                 Morningside,West Hill  43.782601
# 3        M1G  Scarborough                                Woburn  43.759824
# 4        M1H  Scarborough                             Cedarbrae  43.756467
#
#    longitude
# 0 -79.165837
# 1 -79.173334
# 2 -79.204958
# 3 -79.225291
# 4 -79.226692

# %% [markdown]
# <a id="Third_Section"></a>

# %% [markdown]
# #### Third part of the Question starts from Here

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df5['Borough'].unique()),
        len(df5['Neighborhood'].unique())
    )
)
# Out:
# The dataframe has 9 boroughs and 84 neighborhoods.

# %%
neighborhoods =df5

# %% [markdown]
# #### Using geopy library to get the latitude and longitude values of __Toronto__.

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto City are {}, {}.'.format(latitude, longitude))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Toronto City are 43.653963, -79.387207.

# %% [markdown]
# #### Creating a map of __Toronto__ with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['latitude'], neighborhoods['longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I am taking __Etobicoke__ as my sample cluster
#
# Note : I am taking this because, when using __Foursquare API__ we can reduce number of calls for API as Etobicoke has less neighboors.
# Beacuse we only have 950 calls, I am using Etobicoke

# %%
Etobicoke_data = neighborhoods[neighborhoods['Borough'] == 'Etobicoke'].reset_index(drop=True)
Etobicoke_data.head()
# Out:
#   PostalCode    Borough                                       Neighborhood  \
# 0        M8V  Etobicoke                                        New Toronto
# 1        M8W  Etobicoke                              Alderwood,Long Branch
# 2        M8X  Etobicoke                                       The Kingsway
# 3        M8Y  Etobicoke  Humber Bay,King's Mill Park,Mimico NE,Old Mill...
# 4        M8Z  Etobicoke        Mimico NW,The Queensway West,South of Bloor
#
#     latitude  longitude
# 0  43.600763 -79.505264
# 1  43.601717 -79.545232
# 2  43.647381 -79.511333
# 3  43.640046 -79.495028
# 4  43.603656 -79.493178

# %% [markdown]
# #### Get Latitude and Longitude for Etobicoke

# %%
address = 'Etobicoke, Toronto'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Etobicoke are {}, {}.'.format(latitude, longitude))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Etobicoke are 43.6435559, -79.5656326.

# %% [markdown]
# #### Creating a map of __Etobicoke__ with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_Etobicoke = folium.Map(location=[latitude, longitude], zoom_start=12)
# add markers to map
for lat, lng, borough, neighborhood in zip(Etobicoke_data['latitude'], Etobicoke_data['longitude'], Etobicoke_data['Borough'], Etobicoke_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_Etobicoke)  
    
map_Etobicoke
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.

# %% [markdown]
# #### Defining Foursquare Credentials and Version

# %%
CLIENT_ID = 'BHY0KKGDDRBJJZ0M5VPISG5INZ432PUC0G44P0GQLHBFAHT5' # your Foursquare ID
CLIENT_SECRET = '4XHL1P1TRIEPAXZHINM23Y0HOMN5UOHAYEEVOBOHVLPRKFJH' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BHY0KKGDDRBJJZ0M5VPISG5INZ432PUC0G44P0GQLHBFAHT5
# CLIENT_SECRET:4XHL1P1TRIEPAXZHINM23Y0HOMN5UOHAYEEVOBOHVLPRKFJH

# %% [markdown]
# #### Here I'm taking __Kingsview Village__ for exploring

# %%
Etobicoke_data.loc[9, 'Neighborhood']
# Out:
# 'Kingsview Village'

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %%
neighborhood_latitude = Etobicoke_data.loc[9, 'latitude'] # neighborhood latitude value
neighborhood_longitude = Etobicoke_data.loc[9, 'longitude'] # neighborhood longitude value

neighborhood_name = Etobicoke_data.loc[9, 'Neighborhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Kingsview Village are 43.6995391, -79.5563459.

# %% [markdown]
# #### Getting top 50 venues that are in Kingsview Village within a radius of 700 meters.

# %%
#Limiting to 50 to save number of calls

LIMIT = 50 # limit of number of venues returned by Foursquare API

radius = 700 # define radius

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=BHY0KKGDDRBJJZ0M5VPISG5INZ432PUC0G44P0GQLHBFAHT5&client_secret=4XHL1P1TRIEPAXZHINM23Y0HOMN5UOHAYEEVOBOHVLPRKFJH&v=20180605&ll=43.6995391,-79.5563459&radius=700&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5bfe67234c1f6767434dff40'},
#  'response': {'headerLocation': 'Toronto',
#   'headerFullLocation': 'Toronto',
#   'headerLocationGranularity': 'city',
#   'totalResults': 8,
#   'suggestedBounds': {'ne': {'lat': 43.70583910630001,
#     'lng': -79.54764813943873},
#    'sw': {'lat': 43.693239093699994, 'lng': -79.56504366056126}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b462be3f964a520ec1826e3',
#        'name': 'Fitness 365',
#        'location': {'address': '40 Ronson Drive, Unit 2',
#         'crossStreet': 'Kipling Ave.',
#         'lat': 43.6984228592084,
#         'lng': -79.56421141496305,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6984228592084,
#           'lng': -79.56421141496305}],
#         'distance': 645,
#         'postalCode': 'M9W 1B3',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['40 Ronson Drive, Unit 2 (Kipling Ave.)',
#          'Toronto ON M9W 1B3',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b462be3f964a520ec1826e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3484497cc0c9b69768f39a',
#        'name': '401 Diner',
#        'location': {'address': '2-24 Ronson Dr',
#         'lat': 43.700939740345575,
#         'lng': -79.56244301714327,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.700939740345575,
#           'lng': -79.56244301714327}],
#         'distance': 514,
#         'postalCode': 'M9W 1B2',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['2-24 Ronson Dr',
#          'Toronto ON M9W 1B2',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3484497cc0c9b69768f39a-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6d1a3bcf7e41bdcec28285',
#        'name': 'TD Canada Trust',
#        'location': {'address': '1735 Kipling Ave',
#         'lat': 43.69393227905449,
#         'lng': -79.5572267379793,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.69393227905449,
#           'lng': -79.5572267379793}],
#         'distance': 628,
#         'postalCode': 'M9R 2Y8',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1735 Kipling Ave',
#          'Etobicoke ON M9R 2Y8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10a951735',
#          'name': 'Bank',
#          'pluralName': 'Banks',
#          'shortName': 'Bank',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6d1a3bcf7e41bdcec28285-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8aa09c770fb60c894dd4c3',
#        'name': 'The Beer Store',
#        'location': {'address': '1735 Kipling Ave',
#         'crossStreet': 'in Westway Shopping Centre',
#         'lat': 43.6933138,
#         'lng': -79.5572835,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6933138,
#           'lng': -79.5572835}],
#         'distance': 697,
#         'postalCode': 'M9R 2Y8',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1735 Kipling Ave (in Westway Shopping Centre)',
#          'Etobicoke ON M9R 2Y8',
#          'Canada']},
#        'categories': [{'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'shortName': 'Beer Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8aa09c770fb60c894dd4c3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8bf4399f3fb1f7d84dfdbc',
#        'name': 'Shoppers Drug Mart',
#        'location': {'address': '1735 Kipling Ave,Unit 2',
#         'crossStreet': 'at Dixon Rd.',
#         'lat': 43.69329615147781,
#         'lng': -79.55714373741019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.69329615147781,
#           'lng': -79.55714373741019}],
#         'distance': 697,
#         'postalCode': 'M9R 2Y8',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1735 Kipling Ave,Unit 2 (at Dixon Rd.)',
#          'Etobicoke ON M9R 2Y8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8bf4399f3fb1f7d84dfdbc-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcccdc0937ca5935bcbab92',
#        'name': 'Food Basics',
#        'location': {'address': '1735 Kipling Ave.',
#         'crossStreet': 'at Dixon Rd.',
#         'lat': 43.69356062698337,
#         'lng': -79.55740524896947,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.69356062698337,
#           'lng': -79.55740524896947}],
#         'distance': 670,
#         'postalCode': 'M9R 2Y8',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1735 Kipling Ave. (at Dixon Rd.)',
#          'Etobicoke ON M9R 2Y8',
#          'Canada']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcccdc0937ca5935bcbab92-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4ff93ce0275481120f9cb6',
#        'name': 'Country Style',
#        'location': {'address': '1935 Kipling',
#         'lat': 43.694366,
#         'lng': -79.557439,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.694366,
#           'lng': -79.557439}],
#         'distance': 582,
#         'cc': 'CA',
#         'city': 'Toronto',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1935 Kipling', 'Toronto ON', 'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4ff93ce0275481120f9cb6-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c66edf4e1da1b8d68759cc3',
#        'name': "McDonald's",
#        'location': {'address': '1735 Kipling Ave.',
#         'crossStreet': 'in Westway Centre',
#         'lat': 43.69334024107688,
#         'lng': -79.5573835083769,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.69334024107688,
#           'lng': -79.5573835083769}],
#         'distance': 695,
#         'postalCode': 'M9R 2Y8',
#         'cc': 'CA',
#         'city': 'Etobicoke',
#         'state': 'ON',
#         'country': 'Canada',
#         'formattedAddress': ['1735 Kipling Ave. (in Westway Centre)',
#          'Etobicoke ON M9R 2Y8',
#          'Canada']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c66edf4e1da1b8d68759cc3-7'}]}]}}

# %% [markdown]
# From the Foursquare lab in the previous module, we know that all the information is in the *items* key. Before we proceed, let's borrow the **get_category_type** function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we are ready to clean the json and structure it into a *pandas* dataframe.

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                  name      categories        lat        lng
# 0         Fitness 365             Gym  43.698423 -79.564211
# 1           401 Diner  Breakfast Spot  43.700940 -79.562443
# 2     TD Canada Trust            Bank  43.693932 -79.557227
# 3      The Beer Store      Beer Store  43.693314 -79.557283
# 4  Shoppers Drug Mart        Pharmacy  43.693296 -79.557144

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 8 venues were returned by Foursquare.

# %% [markdown]
# ## 2. Explore Neighborhoods in Etobicoke

# %% [markdown]
# #### Creating a function to repeat the same process to all the neighborhoods in Etobicoke

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ##### Geeting venues in Etobicoke

# %%
Etobicoke_venues = getNearbyVenues(names=Etobicoke_data['Neighborhood'],
                                   latitudes=Etobicoke_data['latitude'],
                                   longitudes=Etobicoke_data['longitude']
                                  )
# Out:
# New Toronto
# Alderwood,Long Branch
# The Kingsway
# Humber Bay,King's Mill Park,Mimico NE,Old Mill South,The Queensway East,Royal York South East,Sunnylea
# Mimico NW,The Queensway West,South of Bloor
# Islington Avenue
# Islington,Princess Gardens,West Deane Park
# Markland Wood
# Westmount
# Kingsview Village
# Beaumond Heights,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown
# Northwest

# %%
print(Etobicoke_venues.shape)
Etobicoke_venues.head()
# Out:
# (134, 7)
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  New Toronto              43.600763              -79.505264
# 1  New Toronto              43.600763              -79.505264
# 2  New Toronto              43.600763              -79.505264
# 3  New Toronto              43.600763              -79.505264
# 4  New Toronto              43.600763              -79.505264
#
#                     Venue  Venue Latitude  Venue Longitude      Venue Category
# 0          Huevos Gourmet       43.601188       -79.503717  Mexican Restaurant
# 1  Cellar Door Restaurant       43.600221       -79.507638  Italian Restaurant
# 2          Sweet Olenka's       43.601099       -79.500325        Dessert Shop
# 3      Bombay on the Lake       43.600157       -79.507992   Indian Restaurant
# 4            Albatros Pub       43.599737       -79.510094                 Pub

# %% [markdown]
# Checking how many venues were returned for each neighborhood

# %%
Etobicoke_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Alderwood,Long Branch                                                   9
# Beaumond Heights,Jamestown,Mount Olive,Silverst...                     11
# Humber Bay,King's Mill Park,Mimico NE,Old Mill ...                      3
# Islington Avenue                                                       12
# Islington,Princess Gardens,West Deane Park                             22
# Kingsview Village                                                       1
# Markland Wood                                                           4
# Mimico NW,The Queensway West,South of Bloor                             5
# New Toronto                                                            22
# Northwest                                                              11
# The Kingsway                                                           32
# Westmount                                                               2
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Alderwood,Long Branch                                                    9
# Beaumond Heights,Jamestown,Mount Olive,Silverst...                      11
# Humber Bay,King's Mill Park,Mimico NE,Old Mill ...                       3
# Islington Avenue                                                        12
# Islington,Princess Gardens,West Deane Park                              22
# Kingsview Village                                                        1
# Markland Wood                                                            4
# Mimico NW,The Queensway West,South of Bloor                              5
# New Toronto                                                             22
# Northwest                                                               11
# The Kingsway                                                            32
# Westmount                                                                2
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Alderwood,Long Branch                                   9               9
# Beaumond Heights,Jamestown,Mount Olive,Silverst...     11              11
# Humber Bay,King's Mill Park,Mimico NE,Old Mill ...      3               3
# Islington Avenue                                       12              12
# Islington,Princess Gardens,West Deane Park             22              22
# Kingsview Village                                       1               1
# Markland Wood                                           4               4
# Mimico NW,The Queensway West,South of Bloor             5               5
# New Toronto                                            22              22
# Northwest                                              11              11
# The Kingsway                                           32              32
# Westmount                                               2               2
#
#                                                     Venue Longitude  \
# Neighborhood
# Alderwood,Long Branch                                             9
# Beaumond Heights,Jamestown,Mount Olive,Silverst...               11
# Humber Bay,King's Mill Park,Mimico NE,Old Mill ...                3
# Islington Avenue                                                 12
# Islington,Princess Gardens,West Deane Park                       22
# Kingsview Village                                                 1
# Markland Wood                                                     4
# Mimico NW,The Queensway West,South of Bloor                       5
# New Toronto                                                      22
# Northwest                                                        11
# The Kingsway                                                     32
# Westmount                                                         2
#
#                                                     Venue Category
# Neighborhood
# Alderwood,Long Branch                                            9
# Beaumond Heights,Jamestown,Mount Olive,Silverst...              11
# Humber Bay,King's Mill Park,Mimico NE,Old Mill ...               3
# Islington Avenue                                                12
# Islington,Princess Gardens,West Deane Park                      22
# Kingsview Village                                                1
# Markland Wood                                                    4
# Mimico NW,The Queensway West,South of Bloor                      5
# New Toronto                                                     22
# Northwest                                                       11
# The Kingsway                                                    32
# Westmount                                                        2

# %%
print('There are {} uniques categories.'.format(len(Etobicoke_venues['Venue Category'].unique())))
# Out:
# There are 62 uniques categories.

# %% [markdown]
# ## 3. Analyze Each Neighborhood

# %% [markdown]
# #### One Hot encoding

# %%
# one hot encoding
Etobicoke_onehot = pd.get_dummies(Etobicoke_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
Etobicoke_onehot['Neighborhood'] = Etobicoke_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [Etobicoke_onehot.columns[-1]] + list(Etobicoke_onehot.columns[:-1])
Etobicoke_onehot = Etobicoke_onehot[fixed_columns]

Etobicoke_onehot.tail()
# Out:
#     Neighborhood  African Restaurant  American Restaurant  Asian Restaurant  \
# 129    Northwest                   0                    0                 0
# 130    Northwest                   0                    0                 0
# 131    Northwest                   0                    0                 0
# 132    Northwest                   0                    0                 0
# 133    Northwest                   0                    0                 0
#
#      BBQ Joint  Bakery  Bank  Baseball Field  Beer Store  Big Box Store  \
# 129          0       0     0               0           0              0
# 130          0       0     0               0           0              0
# 131          0       0     0               0           0              0
# 132          0       0     0               0           0              0
# 133          0       0     0               0           0              0
#
#      Bookstore  Breakfast Spot  Burger Joint  Bus Stop  Café  \
# 129          0               0             0         0     0
# 130          0               0             0         0     0
# 131          0               0             0         0     1
# 132          0               0             0         0     0
# 133          0               0             0         0     0
#
#      Caribbean Restaurant  Clothing Store  Coffee Shop  \
# 129                     0               0            0
# 130                     0               0            0
# 131                     0               0            0
# 132                     0               0            0
# 133                     0               1            0
#
#      Construction & Landscaping  Convenience Store  Dessert Shop  \
# 129                           0                  0             0
# 130                           0                  1             0
# 131                           0                  0             0
# 132                           0                  0             0
# 133                           0                  0             0
#
#      Farmers Market  Fast Food Restaurant  Fish & Chips Shop  Flower Shop  \
# 129               0                     0                  0            0
# 130               0                     0                  0            0
# 131               0                     0                  0            0
# 132               0                     0                  0            0
# 133               0                     0                  0            0
#
#      Food  French Restaurant  Fried Chicken Joint  Gastropub  Golf Course  \
# 129     0                  0                    0          0            0
# 130     0                  0                    0          0            0
# 131     0                  0                    0          0            0
# 132     0                  0                    0          0            0
# 133     0                  0                    0          0            0
#
#      Greek Restaurant  Grocery Store  Gym  Home Service  Hotel  \
# 129                 0              0    0             0      0
# 130                 0              0    0             0      0
# 131                 0              0    0             0      0
# 132                 0              0    0             0      1
# 133                 0              0    0             0      0
#
#      Indian Restaurant  Indie Movie Theater  Intersection  Italian Restaurant  \
# 129                  0                    0             0                   0
# 130                  0                    0             0                   0
# 131                  0                    0             0                   0
# 132                  0                    0             0                   0
# 133                  0                    0             0                   0
#
#      Japanese Restaurant  Korean Restaurant  Liquor Store  Mexican Restaurant  \
# 129                    0                  0             0                   0
# 130                    0                  0             0                   0
# 131                    0                  0             0                   0
# 132                    0                  0             0                   0
# 133                    0                  0             0                   0
#
#      Mobile Phone Shop  Park  Pet Store  Pharmacy  Piano Bar  Pizza Place  \
# 129                  0     0          0         0          0            0
# 130                  0     0          0         0          0            0
# 131                  0     0          0         0          0            0
# 132                  0     0          0         0          0            0
# 133                  0     0          0         0          0            0
#
#      Pool Hall  Pub  Record Shop  Restaurant  Sandwich Place  Scenic Lookout  \
# 129          0    0            0           0               1               0
# 130          0    0            0           0               0               0
# 131          0    0            0           0               0               0
# 132          0    0            0           0               0               0
# 133          0    0            0           0               0               0
#
#      Seafood Restaurant  Skating Rink  Smoke Shop  Sushi Restaurant  \
# 129                   0             0           0                 0
# 130                   0             0           0                 0
# 131                   0             0           0                 0
# 132                   0             0           0                 0
# 133                   0             0           0                 0
#
#      Tapas Restaurant  Thai Restaurant  Thrift / Vintage Store  \
# 129                 0                0                       0
# 130                 0                0                       0
# 131                 0                0                       0
# 132                 0                0                       0
# 133                 0                0                       0
#
#      Video Game Store
# 129                 0
# 130                 0
# 131                 0
# 132                 0
# 133                 0

# %%
Etobicoke_onehot.shape
# Out:
# (134, 63)

# %% [markdown]
# #### Grouping rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
Etobicoke_grouped = Etobicoke_onehot.groupby('Neighborhood').mean().reset_index()
Etobicoke_grouped
# Out:
#                                          Neighborhood  African Restaurant  \
# 0                               Alderwood,Long Branch            0.000000
# 1   Beaumond Heights,Jamestown,Mount Olive,Silvers...            0.000000
# 2   Humber Bay,King's Mill Park,Mimico NE,Old Mill...            0.000000
# 3                                    Islington Avenue            0.083333
# 4          Islington,Princess Gardens,West Deane Park            0.000000
# 5                                   Kingsview Village            0.000000
# 6                                       Markland Wood            0.000000
# 7         Mimico NW,The Queensway West,South of Bloor            0.000000
# 8                                         New Toronto            0.000000
# 9                                           Northwest            0.000000
# 10                                       The Kingsway            0.000000
# 11                                          Westmount            0.000000
#
#     American Restaurant  Asian Restaurant  BBQ Joint    Bakery      Bank  \
# 0              0.000000          0.000000   0.000000  0.000000  0.111111
# 1              0.090909          0.000000   0.000000  0.000000  0.090909
# 2              0.000000          0.000000   0.000000  0.000000  0.000000
# 3              0.000000          0.083333   0.000000  0.000000  0.000000
# 4              0.000000          0.000000   0.045455  0.045455  0.000000
# 5              0.000000          0.000000   0.000000  0.000000  0.000000
# 6              0.000000          0.000000   0.000000  0.000000  0.000000
# 7              0.200000          0.000000   0.000000  0.000000  0.000000
# 8              0.000000          0.045455   0.000000  0.045455  0.000000
# 9              0.090909          0.000000   0.000000  0.000000  0.090909
# 10             0.000000          0.000000   0.000000  0.031250  0.031250
# 11             0.000000          0.000000   0.000000  0.000000  0.000000
#
#     Baseball Field  Beer Store  Big Box Store  Bookstore  Breakfast Spot  \
# 0             0.00    0.000000       0.000000   0.000000          0.0000
# 1             0.00    0.000000       0.000000   0.000000          0.0000
# 2             0.00    0.000000       0.000000   0.000000          0.0000
# 3             0.00    0.000000       0.083333   0.083333          0.0000
# 4             0.00    0.045455       0.000000   0.000000          0.0000
# 5             0.00    0.000000       0.000000   0.000000          0.0000
# 6             0.25    0.000000       0.000000   0.000000          0.0000
# 7             0.00    0.000000       0.000000   0.000000          0.0000
# 8             0.00    0.000000       0.000000   0.000000          0.0000
# 9             0.00    0.000000       0.000000   0.000000          0.0000
# 10            0.00    0.000000       0.000000   0.000000          0.0625
# 11            0.00    0.000000       0.000000   0.000000          0.0000
#
#     Burger Joint  Bus Stop      Café  Caribbean Restaurant  Clothing Store  \
# 0        0.00000       0.0  0.000000              0.000000        0.000000
# 1        0.00000       0.0  0.090909              0.000000        0.090909
# 2        0.00000       0.0  0.000000              0.000000        0.000000
# 3        0.00000       0.0  0.000000              0.000000        0.000000
# 4        0.00000       0.0  0.000000              0.045455        0.000000
# 5        0.00000       0.0  0.000000              0.000000        0.000000
# 6        0.00000       0.0  0.000000              0.000000        0.000000
# 7        0.00000       0.2  0.000000              0.000000        0.000000
# 8        0.00000       0.0  0.090909              0.000000        0.000000
# 9        0.00000       0.0  0.090909              0.000000        0.090909
# 10       0.03125       0.0  0.031250              0.000000        0.000000
# 11       0.00000       0.0  0.000000              0.000000        0.000000
#
#     Coffee Shop  Construction & Landscaping  Convenience Store  Dessert Shop  \
# 0      0.111111                    0.000000           0.000000      0.000000
# 1      0.090909                    0.000000           0.090909      0.000000
# 2      0.000000                    0.333333           0.000000      0.000000
# 3      0.000000                    0.000000           0.000000      0.000000
# 4      0.136364                    0.000000           0.045455      0.000000
# 5      0.000000                    0.000000           0.000000      0.000000
# 6      0.000000                    0.000000           0.000000      0.000000
# 7      0.000000                    0.000000           0.000000      0.000000
# 8      0.045455                    0.000000           0.000000      0.045455
# 9      0.090909                    0.000000           0.090909      0.000000
# 10     0.093750                    0.000000           0.000000      0.062500
# 11     0.000000                    0.000000           0.000000      0.000000
#
#     Farmers Market  Fast Food Restaurant  Fish & Chips Shop  Flower Shop  \
# 0         0.000000              0.000000           0.000000     0.000000
# 1         0.090909              0.000000           0.000000     0.000000
# 2         0.000000              0.000000           0.000000     0.000000
# 3         0.000000              0.083333           0.083333     0.000000
# 4         0.000000              0.045455           0.000000     0.000000
# 5         0.000000              0.000000           0.000000     0.000000
# 6         0.000000              0.000000           0.000000     0.000000
# 7         0.000000              0.200000           0.000000     0.000000
# 8         0.000000              0.000000           0.045455     0.045455
# 9         0.090909              0.000000           0.000000     0.000000
# 10        0.000000              0.000000           0.000000     0.000000
# 11        0.000000              0.000000           0.000000     0.000000
#
#         Food  French Restaurant  Fried Chicken Joint  Gastropub  Golf Course  \
# 0   0.000000            0.00000             0.000000    0.00000         0.00
# 1   0.000000            0.00000             0.000000    0.00000         0.00
# 2   0.000000            0.00000             0.000000    0.00000         0.00
# 3   0.083333            0.00000             0.083333    0.00000         0.00
# 4   0.000000            0.00000             0.000000    0.00000         0.00
# 5   0.000000            0.00000             0.000000    0.00000         0.00
# 6   0.000000            0.00000             0.000000    0.00000         0.25
# 7   0.000000            0.00000             0.000000    0.00000         0.00
# 8   0.000000            0.00000             0.045455    0.00000         0.00
# 9   0.000000            0.00000             0.000000    0.00000         0.00
# 10  0.000000            0.03125             0.000000    0.03125         0.00
# 11  0.000000            0.00000             0.000000    0.00000         0.00
#
#     Greek Restaurant  Grocery Store       Gym  Home Service     Hotel  \
# 0            0.00000       0.000000  0.111111      0.000000  0.000000
# 1            0.00000       0.090909  0.090909      0.000000  0.090909
# 2            0.00000       0.000000  0.000000      0.333333  0.000000
# 3            0.00000       0.000000  0.000000      0.000000  0.000000
# 4            0.00000       0.000000  0.045455      0.000000  0.000000
# 5            0.00000       0.000000  0.000000      0.000000  0.000000
# 6            0.00000       0.000000  0.000000      0.000000  0.000000
# 7            0.00000       0.000000  0.000000      0.000000  0.000000
# 8            0.00000       0.045455  0.045455      0.000000  0.000000
# 9            0.00000       0.090909  0.090909      0.000000  0.090909
# 10           0.03125       0.000000  0.000000      0.000000  0.000000
# 11           0.00000       0.000000  0.000000      0.000000  0.000000
#
#     Indian Restaurant  Indie Movie Theater  Intersection  Italian Restaurant  \
# 0            0.000000              0.00000      0.000000            0.000000
# 1            0.000000              0.00000      0.000000            0.000000
# 2            0.000000              0.00000      0.000000            0.000000
# 3            0.000000              0.00000      0.083333            0.000000
# 4            0.000000              0.00000      0.000000            0.045455
# 5            0.000000              0.00000      0.000000            0.000000
# 6            0.000000              0.00000      0.000000            0.000000
# 7            0.000000              0.00000      0.000000            0.000000
# 8            0.045455              0.00000      0.000000            0.045455
# 9            0.000000              0.00000      0.000000            0.000000
# 10           0.031250              0.03125      0.000000            0.062500
# 11           0.000000              0.00000      0.000000            0.000000
#
#     Japanese Restaurant  Korean Restaurant  Liquor Store  Mexican Restaurant  \
# 0              0.000000           0.000000       0.00000            0.000000
# 1              0.000000           0.000000       0.00000            0.000000
# 2              0.000000           0.000000       0.00000            0.000000
# 3              0.000000           0.000000       0.00000            0.000000
# 4              0.045455           0.045455       0.00000            0.000000
# 5              0.000000           0.000000       0.00000            0.000000
# 6              0.000000           0.000000       0.00000            0.000000
# 7              0.000000           0.000000       0.00000            0.000000
# 8              0.000000           0.000000       0.00000            0.090909
# 9              0.000000           0.000000       0.00000            0.000000
# 10             0.000000           0.000000       0.03125            0.000000
# 11             0.000000           0.000000       0.00000            0.000000
#
#     Mobile Phone Shop      Park  Pet Store  Pharmacy  Piano Bar  Pizza Place  \
# 0             0.00000  0.000000        0.0  0.111111       0.00     0.222222
# 1             0.00000  0.000000        0.0  0.000000       0.00     0.000000
# 2             0.00000  0.333333        0.0  0.000000       0.00     0.000000
# 3             0.00000  0.000000        0.0  0.000000       0.00     0.000000
# 4             0.00000  0.000000        0.0  0.000000       0.00     0.045455
# 5             0.00000  1.000000        0.0  0.000000       0.00     0.000000
# 6             0.00000  0.250000        0.0  0.000000       0.25     0.000000
# 7             0.00000  0.000000        0.2  0.000000       0.00     0.000000
# 8             0.00000  0.000000        0.0  0.045455       0.00     0.045455
# 9             0.00000  0.000000        0.0  0.000000       0.00     0.000000
# 10            0.03125  0.000000        0.0  0.031250       0.00     0.031250
# 11            0.00000  0.500000        0.0  0.000000       0.00     0.500000
#
#     Pool Hall       Pub  Record Shop  Restaurant  Sandwich Place  \
# 0     0.00000  0.111111     0.000000    0.000000        0.111111
# 1     0.00000  0.000000     0.000000    0.000000        0.090909
# 2     0.00000  0.000000     0.000000    0.000000        0.000000
# 3     0.00000  0.000000     0.000000    0.083333        0.083333
# 4     0.00000  0.090909     0.000000    0.045455        0.090909
# 5     0.00000  0.000000     0.000000    0.000000        0.000000
# 6     0.00000  0.000000     0.000000    0.000000        0.000000
# 7     0.00000  0.000000     0.000000    0.000000        0.200000
# 8     0.00000  0.045455     0.045455    0.045455        0.000000
# 9     0.00000  0.000000     0.000000    0.000000        0.090909
# 10    0.03125  0.062500     0.000000    0.031250        0.000000
# 11    0.00000  0.000000     0.000000    0.000000        0.000000
#
#     Scenic Lookout  Seafood Restaurant  Skating Rink  Smoke Shop  \
# 0         0.000000             0.00000      0.111111     0.00000
# 1         0.000000             0.00000      0.000000     0.00000
# 2         0.000000             0.00000      0.000000     0.00000
# 3         0.000000             0.00000      0.000000     0.00000
# 4         0.000000             0.00000      0.000000     0.00000
# 5         0.000000             0.00000      0.000000     0.00000
# 6         0.000000             0.00000      0.000000     0.00000
# 7         0.000000             0.00000      0.000000     0.00000
# 8         0.045455             0.00000      0.000000     0.00000
# 9         0.000000             0.00000      0.000000     0.00000
# 10        0.000000             0.03125      0.000000     0.03125
# 11        0.000000             0.00000      0.000000     0.00000
#
#     Sushi Restaurant  Tapas Restaurant  Thai Restaurant  \
# 0           0.000000           0.00000         0.000000
# 1           0.000000           0.00000         0.000000
# 2           0.000000           0.00000         0.000000
# 3           0.000000           0.00000         0.000000
# 4           0.045455           0.00000         0.045455
# 5           0.000000           0.00000         0.000000
# 6           0.000000           0.00000         0.000000
# 7           0.000000           0.00000         0.000000
# 8           0.045455           0.00000         0.000000
# 9           0.000000           0.00000         0.000000
# 10          0.062500           0.03125         0.031250
# 11          0.000000           0.00000         0.000000
#
#     Thrift / Vintage Store  Video Game Store
# 0                 0.000000          0.000000
# 1                 0.000000          0.000000
# 2                 0.000000          0.000000
# 3                 0.000000          0.083333
# 4                 0.045455          0.000000
# 5                 0.000000          0.000000
# 6                 0.000000          0.000000
# 7                 0.000000          0.000000
# 8                 0.000000          0.000000
# 9                 0.000000          0.000000
# 10                0.000000          0.000000
# 11                0.000000          0.000000

# %%
Etobicoke_grouped.shape
# Out:
# (12, 63)

# %% [markdown]
# #### Printing each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in Etobicoke_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Etobicoke_grouped[Etobicoke_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Alderwood,Long Branch----
#           venue  freq
# 0   Pizza Place  0.22
# 1           Gym  0.11
# 2  Skating Rink  0.11
# 3      Pharmacy  0.11
# 4           Pub  0.11
#
#
# ----Beaumond Heights,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown----
#                venue  freq
# 0                Gym  0.09
# 1     Sandwich Place  0.09
# 2  Convenience Store  0.09
# 3        Coffee Shop  0.09
# 4     Clothing Store  0.09
#
#
# ----Humber Bay,King's Mill Park,Mimico NE,Old Mill South,The Queensway East,Royal York South East,Sunnylea----
#                         venue  freq
# 0                        Park  0.33
# 1  Construction & Landscaping  0.33
# 2                Home Service  0.33
# 3          African Restaurant  0.00
# 4                   Piano Bar  0.00
#
#
# ----Islington Avenue----
#                 venue  freq
# 0  African Restaurant  0.08
# 1           Bookstore  0.08
# 2      Sandwich Place  0.08
# 3          Restaurant  0.08
# 4        Intersection  0.08
#
#
# ----Islington,Princess Gardens,West Deane Park----
#             venue  freq
# 0     Coffee Shop  0.14
# 1             Pub  0.09
# 2  Sandwich Place  0.09
# 3             Gym  0.05
# 4      Restaurant  0.05
#
#
# ----Kingsview Village----
#                 venue  freq
# 0                Park   1.0
# 1  African Restaurant   0.0
# 2           Piano Bar   0.0
# 3               Hotel   0.0
# 4   Indian Restaurant   0.0
#
#
# ----Markland Wood----
#                 venue  freq
# 0           Piano Bar  0.25
# 1         Golf Course  0.25
# 2      Baseball Field  0.25
# 3                Park  0.25
# 4  African Restaurant  0.00
#
#
# ----Mimico NW,The Queensway West,South of Bloor----
#                   venue  freq
# 0   American Restaurant   0.2
# 1             Pet Store   0.2
# 2  Fast Food Restaurant   0.2
# 3              Bus Stop   0.2
# 4        Sandwich Place   0.2
#
#
# ----New Toronto----
#                 venue  freq
# 0  Mexican Restaurant  0.09
# 1                Café  0.09
# 2                 Gym  0.05
# 3         Record Shop  0.05
# 4   Indian Restaurant  0.05
#
#
# ----Northwest----
#                venue  freq
# 0                Gym  0.09
# 1     Sandwich Place  0.09
# 2  Convenience Store  0.09
# 3        Coffee Shop  0.09
# 4     Clothing Store  0.09
#
#
# ----The Kingsway----
#                 venue  freq
# 0         Coffee Shop  0.09
# 1                 Pub  0.06
# 2        Dessert Shop  0.06
# 3    Sushi Restaurant  0.06
# 4  Italian Restaurant  0.06
#
#
# ----Westmount----
#                venue  freq
# 0        Pizza Place   0.5
# 1               Park   0.5
# 2          Piano Bar   0.0
# 3              Hotel   0.0
# 4  Indian Restaurant   0.0

# %% [markdown]
# Function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Creating a new dataframe and displaying the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Etobicoke_grouped['Neighborhood']

for ind in np.arange(Etobicoke_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Etobicoke_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                          Neighborhood 1st Most Common Venue  \
# 0                               Alderwood,Long Branch           Pizza Place
# 1   Beaumond Heights,Jamestown,Mount Olive,Silvers...         Grocery Store
# 2   Humber Bay,King's Mill Park,Mimico NE,Old Mill...          Home Service
# 3                                    Islington Avenue      Video Game Store
# 4          Islington,Princess Gardens,West Deane Park           Coffee Shop
# 5                                   Kingsview Village                  Park
# 6                                       Markland Wood           Golf Course
# 7         Mimico NW,The Queensway West,South of Bloor        Sandwich Place
# 8                                         New Toronto                  Café
# 9                                           Northwest         Grocery Store
# 10                                       The Kingsway           Coffee Shop
# 11                                          Westmount           Pizza Place
#
#          2nd Most Common Venue 3rd Most Common Venue   4th Most Common Venue  \
# 0                          Pub           Coffee Shop                     Gym
# 1                         Bank        Clothing Store       Convenience Store
# 2   Construction & Landscaping                  Park        Video Game Store
# 3                   Restaurant      Asian Restaurant           Big Box Store
# 4                          Pub        Sandwich Place  Thrift / Vintage Store
# 5             Video Game Store        Clothing Store               Gastropub
# 6               Baseball Field             Piano Bar                    Park
# 7         Fast Food Restaurant              Bus Stop               Pet Store
# 8           Mexican Restaurant         Grocery Store             Pizza Place
# 9                         Bank        Clothing Store       Convenience Store
# 10            Sushi Restaurant          Dessert Shop      Italian Restaurant
# 11                        Park      Video Game Store          Clothing Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0               Pharmacy          Skating Rink                  Bank
# 1                   Café        Farmers Market        Sandwich Place
# 2       Greek Restaurant             Gastropub   Fried Chicken Joint
# 3              Bookstore  Fast Food Restaurant     Fish & Chips Shop
# 4      Korean Restaurant  Caribbean Restaurant     Convenience Store
# 5    Fried Chicken Joint     French Restaurant                  Food
# 6      French Restaurant                  Food           Flower Shop
# 7    American Restaurant   Fried Chicken Joint     French Restaurant
# 8    Fried Chicken Joint     Fish & Chips Shop          Dessert Shop
# 9                   Café        Farmers Market        Sandwich Place
# 10        Breakfast Spot                   Pub                  Bank
# 11             Gastropub   Fried Chicken Joint     French Restaurant
#
#    8th Most Common Venue 9th Most Common Venue      10th Most Common Venue
# 0         Sandwich Place      Video Game Store  Construction & Landscaping
# 1                  Hotel                   Gym         American Restaurant
# 2      French Restaurant                  Food                 Flower Shop
# 3                   Food   Fried Chicken Joint                Intersection
# 4                    Gym           Pizza Place                  Beer Store
# 5            Flower Shop     Fish & Chips Shop        Fast Food Restaurant
# 6    Fried Chicken Joint        Clothing Store        Fast Food Restaurant
# 7                   Food           Flower Shop           Fish & Chips Shop
# 8                    Gym     Indian Restaurant                 Coffee Shop
# 9                  Hotel                   Gym         American Restaurant
# 10              Pharmacy     Indian Restaurant         Indie Movie Theater
# 11                  Food           Flower Shop           Fish & Chips Shop

# %% [markdown]
# ## 4. Cluster Neighborhoods

# %% [markdown]
# Run *k*-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

Etobicoke_grouped_clustering = Etobicoke_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Etobicoke_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 2, 1, 1, 0, 3, 1, 1, 1], dtype=int32)

# %% [markdown]
# Creating a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
Etobicoke_merged = Etobicoke_data

# add clustering labels
Etobicoke_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
Etobicoke_merged = Etobicoke_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Etobicoke_merged.head() # check the last columns!
# Out:
#   PostalCode    Borough                                       Neighborhood  \
# 0        M8V  Etobicoke                                        New Toronto
# 1        M8W  Etobicoke                              Alderwood,Long Branch
# 2        M8X  Etobicoke                                       The Kingsway
# 3        M8Y  Etobicoke  Humber Bay,King's Mill Park,Mimico NE,Old Mill...
# 4        M8Z  Etobicoke        Mimico NW,The Queensway West,South of Bloor
#
#     latitude  longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.600763 -79.505264               1                  Café
# 1  43.601717 -79.545232               1           Pizza Place
# 2  43.647381 -79.511333               2           Coffee Shop
# 3  43.640046 -79.495028               1          Home Service
# 4  43.603656 -79.493178               1        Sandwich Place
#
#         2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Mexican Restaurant         Grocery Store           Pizza Place
# 1                         Pub           Coffee Shop                   Gym
# 2            Sushi Restaurant          Dessert Shop    Italian Restaurant
# 3  Construction & Landscaping                  Park      Video Game Store
# 4        Fast Food Restaurant              Bus Stop             Pet Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0   Fried Chicken Joint     Fish & Chips Shop          Dessert Shop
# 1              Pharmacy          Skating Rink                  Bank
# 2        Breakfast Spot                   Pub                  Bank
# 3      Greek Restaurant             Gastropub   Fried Chicken Joint
# 4   American Restaurant   Fried Chicken Joint     French Restaurant
#
#   8th Most Common Venue 9th Most Common Venue      10th Most Common Venue
# 0                   Gym     Indian Restaurant                 Coffee Shop
# 1        Sandwich Place      Video Game Store  Construction & Landscaping
# 2              Pharmacy     Indian Restaurant         Indie Movie Theater
# 3     French Restaurant                  Food                 Flower Shop
# 4                  Food           Flower Shop           Fish & Chips Shop

# %% [markdown]
# ## Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Etobicoke_merged['latitude'], Etobicoke_merged['longitude'], Etobicoke_merged['Neighborhood'], Etobicoke_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
