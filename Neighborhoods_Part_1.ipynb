# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto - Part 1

# %% [markdown]
# ## Importing required Libraries

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# #### Assigning wikipedia Article to varibale __url__

# %%
url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %% [markdown]
# ### Prasing wikipedia table using *requests* and *BeautifulSoup*

# %%
req=requests.get(url)
data=req.text
    
soup = BeautifulSoup(data,"html.parser")
table = soup.table

# %% [markdown]
# ### __*'table'*__ now has all the table data in wikipedia article

# %%
table_rows=[] # creating an empty list

# %% [markdown]
# ### Iterating over *'tr'* and *'td'* tags in __'table'__
# When in __*'td'*__ tag, search for __*'a'*__ tag and then get the title of the tag. By doing this we can filter the Grayed Out and Not Assigned cells
#
# Grayed Out and Not Assigned cells will be replaced by __*'None'*__
#
# Extracting HTML table data into __*table_rows*__

# %%
trs=table.find_all('tr')
for tr in trs:
    td = tr.find_all('td')
    if len(td)==0:
        continue
    postal_code = td[0].getText()
    district = td[1].find('a')
    if district is None:
        dist_name = 'None'
    else:
        dist_name = district.getText() 
    Neighborhood = td[2].find('a')
    if Neighborhood is None:
        Neig_hood = 'None'
    else:
        Neig_hood = Neighborhood.getText()
    table_rows.append([postal_code,dist_name,Neig_hood])

# %% [markdown]
# #### Creating Dataframe from __*table_rows*__ and assigning column names

# %%
df=pd.DataFrame(table_rows,columns=['PostalCode','Borough','Neighborhood'])

# %%
df.head()
# Out:
#   PostalCode           Borough      Neighborhood
# 0        M1A              None              None
# 1        M2A              None              None
# 2        M3A        North York         Parkwoods
# 3        M4A        North York  Victoria Village
# 4        M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# #### Filtering the rows which has 'None'.
# __*'None'*__ indicates grayed out and Not assigned cells

# %%
df1=df[df['Neighborhood'] != 'None']

# %%
df2=df1[df1['Borough'] != 'None']

# %%
df3=df2.reset_index()

# %%
df4=df3.drop('index',axis=1)

# %% [markdown]
# #### Below step joins values in Neighborhood column based on postalCode and Borough

# %%
p_codes=df4.groupby(['PostalCode','Borough'])['Neighborhood'].apply(','.join).reset_index()

# %%
p_codes
# Out:
#    PostalCode           Borough  \
# 0         M1B       Scarborough
# 1         M1C       Scarborough
# 2         M1E       Scarborough
# 3         M1G       Scarborough
# 4         M1H       Scarborough
# 5         M1J       Scarborough
# 6         M1K       Scarborough
# 7         M1L       Scarborough
# 8         M1M       Scarborough
# 9         M1N       Scarborough
# 10        M1P       Scarborough
# 11        M1R       Scarborough
# 12        M1S       Scarborough
# 13        M1T       Scarborough
# 14        M1V       Scarborough
# 15        M1W       Scarborough
# 16        M1X       Scarborough
# 17        M2H        North York
# 18        M2J        North York
# 19        M2K        North York
# 20        M2L        North York
# 21        M2M        North York
# 22        M2R        North York
# 23        M3A        North York
# 24        M3C        North York
# 25        M3H        North York
# 26        M3J        North York
# 27        M3K        North York
# 28        M3L        North York
# 29        M4A        North York
# ..        ...               ...
# 54        M5R   Central Toronto
# 55        M5S  Downtown Toronto
# 56        M5T  Downtown Toronto
# 57        M5V  Downtown Toronto
# 58        M5X  Downtown Toronto
# 59        M6A        North York
# 60        M6B        North York
# 61        M6H      West Toronto
# 62        M6J      West Toronto
# 63        M6K      West Toronto
# 64        M6L        North York
# 65        M6M              York
# 66        M6P      West Toronto
# 67        M6R      West Toronto
# 68        M6S      West Toronto
# 69        M8V         Etobicoke
# 70        M8W         Etobicoke
# 71        M8X         Etobicoke
# 72        M8Y         Etobicoke
# 73        M8Z         Etobicoke
# 74        M9A         Etobicoke
# 75        M9B         Etobicoke
# 76        M9C         Etobicoke
# 77        M9L        North York
# 78        M9M        North York
# 79        M9N              York
# 80        M9P         Etobicoke
# 81        M9R         Etobicoke
# 82        M9V         Etobicoke
# 83        M9W         Etobicoke
#
#                                          Neighborhood
# 0                                       Rouge,Malvern
# 1                Highland Creek,Rouge Hill,Port Union
# 2                               Morningside,West Hill
# 3                                              Woburn
# 4                                           Cedarbrae
# 5                                 Scarborough Village
# 6                                Ionview,Kennedy Park
# 7                       Clairlea,Golden Mile,Oakridge
# 8                                Cliffcrest,Cliffside
# 9                                         Birch Cliff
# 10  Dorset Park,Scarborough Town Centre,Wexford He...
# 11                                   Maryvale,Wexford
# 12                                          Agincourt
# 13                                      Tam O'Shanter
# 14                           Agincourt North,Milliken
# 15                                       Steeles West
# 16                                        Upper Rouge
# 17                                  Hillcrest Village
# 18                                         Henry Farm
# 19                                    Bayview Village
# 20                            Silver Hills,York Mills
# 21                             Newtonbrook,Willowdale
# 22                                    Willowdale West
# 23                                          Parkwoods
# 24                                    Flemingdon Park
# 25                      Bathurst Manor,Wilson Heights
# 26                     Northwood Park,York University
# 27                                        CFB Toronto
# 28                                     Downsview West
# 29                                   Victoria Village
# ..                                                ...
# 54                                The Annex,Yorkville
# 55                              University of Toronto
# 56            Chinatown,Grange Park,Kensington Market
# 57  CN Tower,King and Spadina,Railway Lands,South ...
# 58              First Canadian Place,Underground city
# 59                    Lawrence Heights,Lawrence Manor
# 60                                          Glencairn
# 61                                 Dovercourt Village
# 62                            Little Portugal,Trinity
# 63                  Exhibition Place,Parkdale Village
# 64                                    Maple Leaf Park
# 65                Keelesdale,Mount Dennis,Silverthorn
# 66                                          High Park
# 67                              Parkdale,Roncesvalles
# 68                                  Runnymede,Swansea
# 69                                        New Toronto
# 70                              Alderwood,Long Branch
# 71                                       The Kingsway
# 72  Humber Bay,King's Mill Park,Mimico NE,Old Mill...
# 73        Mimico NW,The Queensway West,South of Bloor
# 74                                   Islington Avenue
# 75         Islington,Princess Gardens,West Deane Park
# 76                                      Markland Wood
# 77                                      Humber Summit
# 78                                    Emery,Humberlea
# 79                                             Weston
# 80                                          Westmount
# 81                                  Kingsview Village
# 82  Beaumond Heights,Jamestown,Mount Olive,Silvers...
# 83                                          Northwest
#
# [84 rows x 3 columns]

# %%
p_codes.shape
# Out:
# (84, 3)
